# %%
import pandas as pd,numpy as np
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6596\3099695635.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd,numpy as np

# %%
d={"Name":['A','B','A','C','A','B','C','B','C'],"Marks":[17,14,16,18,14,13,12,20,21]}
df=pd.DataFrame(d)

# %%
df
# Out:
#   Name  Marks
# 0    A     17
# 1    B     14
# 2    A     16
# 3    C     18
# 4    A     14
# 5    B     13
# 6    C     12
# 7    B     20
# 8    C     21

# %%
mean_class = df['Marks'].mean()
print(f'The average performance of class {mean_class}')
# Out:
# The average performance of class 16.11111111111111

# %% [markdown]
# syntax:
# `dataframe`.`groupby(col_name)`[col_for_aggreagation].aggreagation_fun()

# %%
df.groupby('Name')['Marks'].mean()
# Out:
# Name
# A    15.666667
# B    15.666667
# C    17.000000
# Name: Marks, dtype: float64

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'Kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

# %%
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby('Team')['Points'].mean()
# Out:
# Team
# Devils    768.00
# Kings     774.25
# Riders    762.25
# Royals    752.50
# Name: Points, dtype: float64

# %%
df.groupby(['Team','Year'])['Points'].mean()
# Out:
# Team    Year
# Devils  2014    863.0
#         2015    673.0
# Kings   2014    741.0
#         2015    812.0
#         2016    756.0
#         2017    788.0
# Riders  2014    876.0
#         2015    789.0
#         2016    694.0
#         2017    690.0
# Royals  2014    701.0
#         2015    804.0
# Name: Points, dtype: float64

# %%
dt = df.groupby('Year')

# %%
for i in dt:
    print(i[1])
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 10  Royals     1  2015     804
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %% [markdown]
# ### Agenda
# 1. Concat : concat function in pandas helps to concatinate one or more then one dataframe based row and columns.
#    - `syntax: pd.concat([df1,df2,...dfn],axis=0:row/1:column)` *bydefault axis = 0.
# 3. Merge(joins) : merge in pandas helps to perform joining like inner,right,left,outer,cross based on similar column.
#    - `syntax`
#    - `pd.merge(df1,df2,how='inner',on='similar_column_name')`
#    - or
#    - `df1.merge(df2,how='inner',on='similar_column_name')`

# %%
# df = pd.read_csv('course.csv',header=None,names=['sr. no','city','institute','course','state','duration'])

# %%
df
# Out:
#     sr. no       city                 institute        course state   duration
# 0        1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1        2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2        3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3        4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4        5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5        6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6        7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7        8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8        9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9       10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10      11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %% [markdown]
#    - `syntax: pd.concat([df1,df2,...dfn],axis=0:row/1:column)` *bydefault axis = 0.

# %%
df1= df.iloc[0:13,:]
df2= df.iloc[13:,:]

# %%
df1
# Out:
#     sr. no       city                institute        course state   duration
# 0        1     Mumbai       PQR institute .Pvt            BI    MH   9 Months
# 1        2      Delhi   ABC institute .Pvt.LTD            AI    UP  18 Months
# 2        3  Bengaluru      MNO  institute .Ltd  Data Science    TN  11 Months
# 3        4     Bhopal  RST  institute .Pvt.LTD            ML    MP   3 Months
# 4        5     Mumbai  EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5        6  Hyderabad          LMN  institute          Could    AP   4 Months
# 6        7      Patna     DEF   institute .Ltd      Web Serv    BH   4 Months
# 7        8    Channai  PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8        9    Kolkata      UVW  institute .Ltd    Networking    WB   3 Months
# 9       10  Hyderabad     GHI   institute .Ltd            AI    AP  18 Months
# 10      11     Bhopal         IJK   institute             DL    MP   3 Months
# ...

# %%
df2
# Out:
#     sr. no       city                 institute        course state   duration
# 13      14     Mumbai   XYZ  institute .Pvt.LTD         Could    MH   3 Months
# 14      15      Patna       NOP  institute .Ltd           AWS    BH   3 Months
# 15      16      Surat       QRS  institute .Ltd            ML    GJ   3 Months
# 16      17      Delhi           WXY  institute            AWS    UP   3 Months
# 17      18     Mumbai          ZAB   institute       Web Serv    MH   4 Months
# 18      19       Pune       CDE  institute .Ltd  Data Science    MH  11 Months
# 19      20  Bengaluru   JKL  institute .Pvt.LTD            AI    TN  18 Months
# 20      21      Surat           INS   institute  Data Science    Gj  11 Months
# 21      22  Hyderabad       ZAP  institute .Ltd            ML    AP   3 Months
# 22      23     Mumbai  XCAD  institute .Pvt.LTD            DL    MH   3 Months
# 23      24    Channai          MTK   institute          Could    KT   4 Months
# ...

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     sr. no       city                 institute        course state   duration
# 0        1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1        2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2        3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3        4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4        5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5        6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6        7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7        8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8        9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9       10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10      11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     sr. no       city                institute        course state   duration  \
# 0      1.0     Mumbai       PQR institute .Pvt            BI    MH   9 Months
# 1      2.0      Delhi   ABC institute .Pvt.LTD            AI    UP  18 Months
# 2      3.0  Bengaluru      MNO  institute .Ltd  Data Science    TN  11 Months
# 3      4.0     Bhopal  RST  institute .Pvt.LTD            ML    MP   3 Months
# 4      5.0     Mumbai  EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5      6.0  Hyderabad          LMN  institute          Could    AP   4 Months
# 6      7.0      Patna     DEF   institute .Ltd      Web Serv    BH   4 Months
# 7      8.0    Channai  PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8      9.0    Kolkata      UVW  institute .Ltd    Networking    WB   3 Months
# 9     10.0  Hyderabad     GHI   institute .Ltd            AI    AP  18 Months
# 10    11.0     Bhopal         IJK   institute             DL    MP   3 Months
# ...

# %% [markdown]
# ### dict or dataframe

# %%
school = {'name':'sandip','roll_no':67}

# %%
school
# Out:
# {'name': 'sandip', 'roll_no': 67}

# %%
school['marks'] = 34

# %%
school
# Out:
# {'name': 'sandip', 'roll_no': 67, 'marks': 34}

# %%
df
# Out:
#     sr. no       city                 institute        course state   duration
# 0        1     Mumbai        PQR institute .Pvt            BI    MH   9 Months
# 1        2      Delhi    ABC institute .Pvt.LTD            AI    UP  18 Months
# 2        3  Bengaluru       MNO  institute .Ltd  Data Science    TN  11 Months
# 3        4     Bhopal   RST  institute .Pvt.LTD            ML    MP   3 Months
# 4        5     Mumbai   EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5        6  Hyderabad           LMN  institute          Could    AP   4 Months
# 6        7      Patna      DEF   institute .Ltd      Web Serv    BH   4 Months
# 7        8    Channai   PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8        9    Kolkata       UVW  institute .Ltd    Networking    WB   3 Months
# 9       10  Hyderabad      GHI   institute .Ltd            AI    AP  18 Months
# 10      11     Bhopal          IJK   institute             DL    MP   3 Months
# ...

# %%
patna, BH

# %%
# df = school , address = marks
df['address'] = df['city']+', '+df['state']

# %%
df
# Out:
#     sr. no       city                 institute        course state  \
# 0        1     Mumbai        PQR institute .Pvt            BI    MH
# 1        2      Delhi    ABC institute .Pvt.LTD            AI    UP
# 2        3  Bengaluru       MNO  institute .Ltd  Data Science    TN
# 3        4     Bhopal   RST  institute .Pvt.LTD            ML    MP
# 4        5     Mumbai   EFG  institute .Pvt.LTD            DL    MH
# 5        6  Hyderabad           LMN  institute          Could    AP
# 6        7      Patna      DEF   institute .Ltd      Web Serv    BH
# 7        8    Channai   PQR  institute .Pvt.LTD           AWS    KT
# 8        9    Kolkata       UVW  institute .Ltd    Networking    WB
# 9       10  Hyderabad      GHI   institute .Ltd            AI    AP
# 10      11     Bhopal          IJK   institute             DL    MP
# 11      12       Pune      KLM   institute .Ltd  Data Science    MH
# 12      13      Delhi       STU  institute .Ltd            BI    UP
# ...

# %%
df3 = df.loc[0:13,'address']

# %%
df3
# Out:
# 0        Mumbai, MH
# 1         Delhi, UP
# 2     Bengaluru, TN
# 3        Bhopal, MP
# 4        Mumbai, MH
# 5     Hyderabad, AP
# 6         Patna, BH
# 7       Channai, KT
# 8       Kolkata, WB
# 9     Hyderabad, AP
# 10       Bhopal, MP
# 11         Pune, MH
# 12        Delhi, UP
# 13       Mumbai, MH
# Name: address, dtype: object

# %%
# concatinate df1 and df3
pd.concat([df1,df3],axis=1)
# Out:
#     sr. no       city                institute        course state   duration  \
# 0      1.0     Mumbai       PQR institute .Pvt            BI    MH   9 Months
# 1      2.0      Delhi   ABC institute .Pvt.LTD            AI    UP  18 Months
# 2      3.0  Bengaluru      MNO  institute .Ltd  Data Science    TN  11 Months
# 3      4.0     Bhopal  RST  institute .Pvt.LTD            ML    MP   3 Months
# 4      5.0     Mumbai  EFG  institute .Pvt.LTD            DL    MH   3 Months
# 5      6.0  Hyderabad          LMN  institute          Could    AP   4 Months
# 6      7.0      Patna     DEF   institute .Ltd      Web Serv    BH   4 Months
# 7      8.0    Channai  PQR  institute .Pvt.LTD           AWS    KT   3 Months
# 8      9.0    Kolkata      UVW  institute .Ltd    Networking    WB   3 Months
# 9     10.0  Hyderabad     GHI   institute .Ltd            AI    AP  18 Months
# 10    11.0     Bhopal         IJK   institute             DL    MP   3 Months
# ...

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'Kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df2 = pd.DataFrame(ipl_data)

# %%
df2
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
d1=df2.iloc[6:,:]
d2=df2.iloc[:5,:]

# %%
d1
# Out:
#       Team  Rank  Year  Points
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
d2
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741

# %%
#new DF from above 2 using concat axis=1 col-wise
df3=pd.concat([d1,d2],axis=1)

# %%
df3
# Out:
#       Team  Rank    Year  Points    Team  Rank    Year  Points
# 6    Kings   1.0  2016.0   756.0     NaN   NaN     NaN     NaN
# 7    Kings   1.0  2017.0   788.0     NaN   NaN     NaN     NaN
# 8   Riders   2.0  2016.0   694.0     NaN   NaN     NaN     NaN
# 9   Royals   4.0  2014.0   701.0     NaN   NaN     NaN     NaN
# 10  Royals   1.0  2015.0   804.0     NaN   NaN     NaN     NaN
# 11  Riders   2.0  2017.0   690.0     NaN   NaN     NaN     NaN
# 0      NaN   NaN     NaN     NaN  Riders   1.0  2014.0   876.0
# 1      NaN   NaN     NaN     NaN  Riders   2.0  2015.0   789.0
# 2      NaN   NaN     NaN     NaN  Devils   2.0  2014.0   863.0
# 3      NaN   NaN     NaN     NaN  Devils   3.0  2015.0   673.0
# 4      NaN   NaN     NaN     NaN   Kings   3.0  2014.0   741.0

# %%
#by default row-wise
df3=pd.concat([d1,d2])

# %%
df3
# Out:
#       Team  Rank  Year  Points
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741

# %%
#group-by
#df.groupby(['Team','Year'])['Points'].mean()

# %%
#groupby([which_col_to_group])[based_on_which_col]
dd=df3.groupby(["Team","Rank"])["Year"]

# %%
#to get accurate anwser iterate over it
for i in dd:
    print(i[1])
# Out:
# 2    2014
# Name: Year, dtype: int64
# 3    2015
# Name: Year, dtype: int64
# 6    2016
# 7    2017
# Name: Year, dtype: int64
# 4    2014
# Name: Year, dtype: int64
# 0    2014
# Name: Year, dtype: int64
# 8     2016
# 11    2017
# 1     2015
# Name: Year, dtype: int64
# 10    2015
# Name: Year, dtype: int64
# 9    2014
# Name: Year, dtype: int64
